# %% [markdown]
# # Método 2: Tiempos de Retorno
#
# Distribución estacionaria π mediante **πᵢ = 1/E[Tᵢ]**

# %%
import sys, os
sys.path.append(os.path.join(os.path.dirname('__file__'), '..'))

from src.markov_matrix import crear_matriz_probabilidad, calcular_distribucion_metodo_tiempo_retorno
import numpy as np
import pandas as pd
import time

# %%
max_n = 200
grid_n = np.arange(10, max_n)
grid_p = np.arange(0.1, 1, 0.1)

print(f"Configuración: n=[10-{max_n-10}], p=[0.1-0.9]")
print(f"Total: {len(grid_n)} × {len(grid_p)} = {len(grid_n) * len(grid_p)} combinaciones")
# Out:
# Configuración: n=[10-190], p=[0.1-0.9]
# Total: 190 × 9 = 1710 combinaciones

# %% [markdown]
# ## Benchmark: Variación de n y p

# %%
matriz_tiempos = np.zeros((len(grid_p), len(grid_n)))

for i, p in enumerate(grid_p):
    for j, n in enumerate(grid_n):
        matriz = crear_matriz_probabilidad(n, p)
        
        start_time = time.time()
        pi = calcular_distribucion_metodo_tiempo_retorno(matriz)
        tiempo = time.time() - start_time
        
        matriz_tiempos[i, j] = tiempo

df_tiempos = pd.DataFrame(matriz_tiempos, 
                         index=[f'p={p:.1f}' for p in grid_p],
                         columns=[f'n={n}' for n in grid_n])

print("\nMatriz de tiempos (segundos):")
display(df_tiempos)
# Out:
# Matriz de tiempos (segundos):
#            n=10      n=11      n=12      n=13      n=14      n=15      n=16  \
# p=0.1  0.001669  0.000864  0.001007  0.000310  0.000319  0.000279  0.000344
# p=0.2  0.000293  0.000336  0.000329  0.000392  0.000419  0.000476  0.000517
# p=0.3  0.000295  0.000306  0.000356  0.000420  0.000433  0.000498  0.000518
# p=0.4  0.000342  0.000307  0.000359  0.000400  0.000462  0.000466  0.000517
# p=0.5  0.000304  0.000406  0.000328  0.000370  0.000432  0.000471  0.000509
# p=0.6  0.000206  0.000135  0.000140  0.000159  0.000171  0.000190  0.000203
# p=0.7  0.000326  0.000432  0.000297  0.000373  0.000398  0.000404  0.000388
# p=0.8  0.000375  0.000310  0.000313  0.000371  0.000458  0.000437  0.000493
# p=0.9  0.000167  0.000151  0.000227  0.000169  0.000174  0.000274  0.000332
#
#            n=17      n=18      n=19  ...     n=190     n=191     n=192  \
# p=0.1  0.000363  0.000449  0.000296  ...  0.066027  0.082405  0.069414
# ...

# %%
df_tiempos.to_csv('../resultados/matriz_tiempos_sistema_lineal.csv')
print("Resultados guardados en resultados/matriz_tiempos_sistema.csv")
# Out:
# Resultados guardados en resultados/matriz_tiempos_sistema.csv
